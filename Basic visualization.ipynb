# %%
import pandas as pd

# %% [markdown]
# ## Get data

# %%
data_URL='https://data.austintexas.gov/api/views/7d8e-dm7r/rows.csv?accessType=DOWNLOAD'

from urllib.request import urlretrieve
urlretrieve(data_URL,'austin_mobility_data')
# Out:
# ('austin_mobility_data', <http.client.HTTPMessage at 0x19516f0a6d8>)

# %%
data_raw = pd.read_csv('austin_mobility_data')
data_raw.head()
# Out:
#                                      ID                             Device ID  \
# 0  6865731e-5e4b-4819-9435-4e62e09a652d  08c8c852-257c-49ad-a14f-727bfc79626d
# 1  08dc0d9c-735e-4006-b9af-60011509e469  255716b5-4a9f-4efc-9967-7a65b3521bac
# 2  92b80c20-89a4-4c7f-8b61-81a3570a218e  4d1e7bd0-75ce-401c-a802-8dd87122f802
# 3  d9aef7c5-025d-4f2c-bafe-7801f89ef9dd  fdc38815-fe35-454b-bfb9-a63a2f2c205b
# 4  baec3b6e-66f1-4043-bbd5-d54087f1c2de  007f1fed-0fe6-423f-8ca7-cd67834f20da
#
#   Vehicle Type  Trip Duration  Trip Distance              Start Time  \
# 0          NaN            NaN            NaN                     NaN
# 1      bicycle     11491603.0         1658.0  11/30/2018 11:00:00 AM
# 2      scooter          678.0         2785.0  04/27/2019 03:00:00 PM
# 3      scooter          713.0         2466.0  04/27/2019 03:00:00 PM
# 4      scooter          469.0         1608.0  04/27/2019 03:15:00 PM
#
#                  End Time           Modified Date  Month  Hour  Day of Week  \
# ...

# %%
data_raw.to_csv('austin_mobility_data.csv')
